# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import inflection
import math
import numpy as np

# %% [markdown]
# #### 0.1 Helper Fuctions

# %% [markdown]
# #### Loading Data

# %%
df_sales_raw = pd.read_csv('/home/IvanBertaci/Documentos/CIENCIAS_DADOS/COMUNIDADEDS/DS_PRODUCAO/ds_em_producao-main/REPOS/train.csv', low_memory=False)
df_store_raw = pd.read_csv('/home/IvanBertaci/Documentos/CIENCIAS_DADOS/COMUNIDADEDS/DS_PRODUCAO/ds_em_producao-main/REPOS/store.csv', low_memory=False)

# merge

df_raw = pd.merge(df_sales_raw, df_store_raw, how='left', on='Store')

# %% [markdown]
# # 1.0 Descrição dos dados

# %%
df1 = df_raw.copy()

# %% [markdown]
# #### 1.1 Rename Columns

# %%
cols_old = ['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
       'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
       'CompetitionDistance', 'CompetitionOpenSinceMonth',
       'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
       'Promo2SinceYear', 'PromoInterval']

snakecase = lambda x: inflection.underscore(x)

cols_new = list(map(snakecase, cols_old))

# rename columns

df1.columns = cols_new

# %% [markdown]
# #### 1.2 Data Dimensions

# %%
print('Number of Rows: {}'.format(df1.shape[0]))
print('Number of Cols: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 1017209
# Number of Cols: 18

# %% [markdown]
# #### 1.3 Data Types

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1.dtypes
# Out:
# store                                    int64
# day_of_week                              int64
# date                            datetime64[ns]
# sales                                    int64
# customers                                int64
# open                                     int64
# promo                                    int64
# state_holiday                           object
# school_holiday                           int64
# store_type                              object
# assortment                              object
# competition_distance                   float64
# competition_open_since_month           float64
# competition_open_since_year            float64
# promo2                                   int64
# promo2_since_week                      float64
# promo2_since_year                      float64
# promo_interval                          object
# dtype: object

# %% [markdown]
# #### 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# store                                0
# day_of_week                          0
# date                                 0
# sales                                0
# customers                            0
# open                                 0
# promo                                0
# state_holiday                        0
# school_holiday                       0
# store_type                           0
# assortment                           0
# competition_distance              2642
# competition_open_since_month    323348
# competition_open_since_year     323348
# promo2                               0
# promo2_since_week               508031
# promo2_since_year               508031
# promo_interval                  508031
# dtype: int64

# %% [markdown]
# #### 1.5 Fillout NA

# %%
#competition_distance 
# Este código converte NA em uma distância de 20000 metros. As NA aconteceram, pois não havia empresas concorrente próximas, desta forma, após verificar qual era a distancia maxima - df1[competition_distance].max(), foi inserido um número maior - 200000, para não ser reconhecido como NA, assim a coluna agora está zerada

df1['competition_distance'] = df1['competition_distance'].apply(lambda x: 200000.0 if math.isnan(x) else x)

#competition_open_since_month
# Este código converte NA para a coluna 'date'. A coluna 'date' é a data de fundação da loja, assim é possível partir do pressuposto que a loja já foi criada com algum concorrente por perto.

df1['competition_open_since_month'] = df1.apply(lambda x: x['date'].month if math.isnan(x['competition_open_since_month']) else x['competition_open_since_month'], axis=1)

#competition_open_since_year
# Este código converte NA para a coluna 'date'. A coluna 'date' é a data de fundação da loja, assim é possível partir do pressuposto que a loja já foi criada com algum concorrente por perto.

df1['competition_open_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['competition_open_since_year']) else x['competition_open_since_year'], axis=1)

#promo2
#promo2_since_week
# Este código converte NA para a coluna 'date'.

df1['promo2_since_week'] = df1.apply(lambda x: x['date'].week if math.isnan(x['promo2_since_week']) else x['promo2_since_week'], axis=1)

#promo2_since_year
# Este código converte NA para a coluna 'date'.

df1['promo2_since_year'] = df1.apply(lambda x: x['date'].year if math.isnan(x['promo2_since_year']) else x['promo2_since_year'], axis=1)

#promo_interval
# Este código converte NA em meses

month_map = {1: 'Jan',  2: 'Fev',  3: 'Mar',  4: 'Apr',  5: 'May',  6: 'Jun',  7: 'Jul',  8: 'Aug',  9: 'Sep',  10: 'Oct', 11: 'Nov', 12: 'Dec'}

df1['promo_interval'].fillna(0, inplace=True )

df1['month_map'] = df1['date'].dt.month.map( month_map )

df1['is_promo'] = df1[['promo_interval', 'month_map']].apply( lambda x: 0 if x['promo_interval'] == 0 else 1 if x['month_map'] in x['promo_interval'].split( ',' ) else 0, axis=1 )

# %%
df1.isna().sum()
# Out:
# store                           0
# day_of_week                     0
# date                            0
# sales                           0
# customers                       0
# open                            0
# promo                           0
# state_holiday                   0
# school_holiday                  0
# store_type                      0
# assortment                      0
# competition_distance            0
# competition_open_since_month    0
# competition_open_since_year     0
# promo2                          0
# promo2_since_week               0
# promo2_since_year               0
# promo_interval                  0
# month_map                       0
# is_promo                        0
# dtype: int64

# %%
df1.sample(20).T
# Out:
#                                           316126               532391   \
# store                                         329                  207
# day_of_week                                     2                    2
# date                          2014-10-07 00:00:00  2014-03-11 00:00:00
# sales                                        7093                 9272
# customers                                     629                 1214
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  1                    0
# store_type                                      a                    a
# assortment                                      a                    a
# competition_distance                         1310                 6870
# competition_open_since_month                    6                    3
# competition_open_since_year                  1990                 2014
# promo2                                          1                    0
# promo2_since_week                              22                   11
# promo2_since_year                            2012                 2014
# promo_interval                   Mar,Jun,Sept,Dec                    0
# month_map                                     Oct                  Mar
# is_promo                                        0                    0
#
#                                           863924               517140   \
# store                                         585                  566
# day_of_week                                     6                    2
# date                          2013-05-18 00:00:00  2014-03-25 00:00:00
# sales                                        4684                 4247
# customers                                     802                  517
# open                                            1                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    a
# assortment                                      c                    a
# competition_distance                          440                 3620
# competition_open_since_month                    4                    3
# competition_open_since_year                  2014                 2014
# promo2                                          0                    1
# promo2_since_week                              20                   40
# promo2_since_year                            2013                 2013
# promo_interval                                  0      Jan,Apr,Jul,Oct
# month_map                                     May                  Mar
# is_promo                                        0                    0
#
#                                           855863               294847   \
# store                                         329                  593
# day_of_week                                     6                    4
# date                          2013-05-25 00:00:00  2014-10-30 00:00:00
# sales                                        4391                10471
# customers                                     410                 1427
# open                                            1                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      a                    a
# assortment                                      a                    c
# competition_distance                         1310                33060
# competition_open_since_month                    6                    3
# competition_open_since_year                  1990                 2010
# promo2                                          1                    0
# promo2_since_week                              22                   44
# promo2_since_year                            2012                 2014
# promo_interval                   Mar,Jun,Sept,Dec                    0
# month_map                                     May                  Oct
# is_promo                                        0                    0
#
#                                           530914               354060   \
# store                                         960                  964
# day_of_week                                     4                    4
# date                          2014-03-13 00:00:00  2014-08-28 00:00:00
# sales                                        4594                 7704
# customers                                     436                 1287
# open                                            1                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    1
# store_type                                      d                    a
# assortment                                      a                    a
# competition_distance                         8990                  270
# competition_open_since_month                    3                    8
# competition_open_since_year                  2014                 2014
# promo2                                          1                    1
# promo2_since_week                              31                    5
# promo2_since_year                            2009                 2013
# promo_interval                    Feb,May,Aug,Nov      Feb,May,Aug,Nov
# month_map                                     Mar                  Aug
# is_promo                                        0                    1
#
#                                           248713               931557   \
# store                                         222                  203
# day_of_week                                     4                    1
# date                          2014-12-18 00:00:00  2013-03-18 00:00:00
# sales                                        6831                 7477
# customers                                     690                  839
# open                                            1                    1
# promo                                           1                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      a                    c
# assortment                                      a                    c
# competition_distance                         2170                  490
# competition_open_since_month                   11                   11
# competition_open_since_year                  2008                 2002
# promo2                                          0                    0
# promo2_since_week                              51                   12
# promo2_since_year                            2014                 2013
# promo_interval                                  0                    0
# month_map                                     Dec                  Mar
# is_promo                                        0                    0
#
#                                           527322               485792   \
# store                                         713                  438
# day_of_week                                     7                    2
# date                          2014-03-16 00:00:00  2014-04-22 00:00:00
# sales                                           0                 4476
# customers                                       0                  515
# open                                            0                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    1
# store_type                                      a                    d
# assortment                                      c                    c
# competition_distance                          220                 1110
# competition_open_since_month                    3                    4
# competition_open_since_year                  2014                 2014
# promo2                                          1                    1
# promo2_since_week                              10                   40
# promo2_since_year                            2014                 2012
# promo_interval                    Jan,Apr,Jul,Oct      Jan,Apr,Jul,Oct
# month_map                                     Mar                  Apr
# is_promo                                        0                    1
#
#                                           476713               74261    \
# store                                         279                  672
# day_of_week                                     3                    2
# date                          2014-04-30 00:00:00  2015-05-26 00:00:00
# sales                                       12508                 8727
# customers                                     922                 1290
# open                                            1                    1
# promo                                           1                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    c
# assortment                                      c                    a
# competition_distance                         2320                  240
# competition_open_since_month                    4                    9
# competition_open_since_year                  2014                 2002
# promo2                                          1                    0
# promo2_since_week                              40                   22
# promo2_since_year                            2012                 2015
# promo_interval                    Jan,Apr,Jul,Oct                    0
# month_map                                     Apr                  May
# is_promo                                        1                    0
#
#                                           328243               1005891  \
# store                                         286                  947
# day_of_week                                     3                    5
# date                          2014-09-24 00:00:00  2013-01-11 00:00:00
# sales                                        3158                 8372
# customers                                     324                 1103
# open                                            1                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      a                    a
# assortment                                      a                    a
# competition_distance                         1460                  460
# competition_open_since_month                    4                    3
# competition_open_since_year                  2015                 2014
# promo2                                          0                    1
# promo2_since_week                              39                   13
# promo2_since_year                            2014                 2010
# promo_interval                                  0      Jan,Apr,Jul,Oct
# month_map                                     Sep                  Jan
# is_promo                                        0                    1
#
#                                           713699               655135   \
# store                                         885                  301
# day_of_week                                     1                    4
# date                          2013-09-30 00:00:00  2013-11-21 00:00:00
# sales                                        4236                 5803
# customers                                     613                  614
# open                                            1                    1
# promo                                           0                    1
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      a                    a
# assortment                                      a                    c
# competition_distance                          480                 4510
# competition_open_since_month                   12                    3
# competition_open_since_year                  2005                 2015
# promo2                                          0                    0
# promo2_since_week                              40                   47
# promo2_since_year                            2013                 2013
# promo_interval                                  0                    0
# month_map                                     Sep                  Nov
# is_promo                                        0                    0
#
#                                           240863               832940
# store                                         889                  821
# day_of_week                                     6                    6
# date                          2014-12-27 00:00:00  2013-06-15 00:00:00
# sales                                        3791                 4813
# customers                                     373                  641
# open                                            1                    1
# promo                                           0                    0
# state_holiday                                   0                    0
# school_holiday                                  0                    0
# store_type                                      d                    a
# assortment                                      a                    a
# competition_distance                        18670                 1700
# competition_open_since_month                   12                    9
# competition_open_since_year                  2005                 2009
# promo2                                          0                    0
# promo2_since_week                              52                   24
# promo2_since_year                            2014                 2013
# promo_interval                                  0                    0
# month_map                                     Dec                  Jun
# is_promo                                        0                    0
